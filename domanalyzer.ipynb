# %% [markdown]
# # Goal
# ### General Goal
# Obtain interesting insights into the data (specifically the units) of Dominions 4
# ### Specific Goals
# - Determine common base units e.g. human

# %% [markdown]
# # Dataset Info
# \* Unverified
#
# |Table|Size    |Description|Relations|
# |-----|--------|-----------|---------|
# |BaseU|2919x304|Unit info  |None     |
# |BaseI|?x?     |Item info  |None     |

# %% [markdown]
# ## BaseU
#
# |Attribute|dtype   |Req|Description|
# |---------|--------|---|-----------|
# |id       |uint    | Y |Unique identifier, some values are skipped|
# |name     |string  | Y |Textual identifier|
# |wpn1     |uint    | N |Foreign key for 1st weapon|
# |wpn2     |uint    | N |Foreign key for 2nd weapon|
# |wpn3     |uint    | N |Foreign key for 3rd weapon|
# |wpn4     |uint    | N |Foreign key for 4th weapon|
# |wpn5     |uint    | N |Foreign key for 5th weapon|
# |wpn6     |uint    | N |Foreign key for 6th weapon|
# |wpn7     |uint    | N |Foreign key for 7th weapon|
# |armor1   |uint    | N |Foreign key for 1st armor|
# |armor2   |uint    | N |Foreign key for 2nd armor|
# |armor3   |uint    | N |Foreign key for 3rd armor|
# |armor4   |uint    | N |Foreign key for 4th armor|
# |rt       |uint    | Y |Number of turns to recruit*|
# |reclimit |uint    | N |Max number of unit that can be recruited at once*|
# |basecost |uint    | Y |?|
# |gmon     |int     | N |?|
# |gcom     |int     | N |?|
# |rcost    |int     | Y |?|
# |size     |category| Y |Physical size of unit, 1-6|
# |ressize  |uint    | Y |?|
# |hp       |uint    | Y |?|
# |prot     |uint    | Y |?|
# |mr       |uint    | Y |?|
# |mor      |uint    | Y |?|
# |str      |uint    | Y |?|
# |att      |uint    | Y |?|
# |def      |uint    | Y |?|
# |prec     |uint    | Y |?|
# |enc      |uint    | Y |?|
# |mapmove       |uint  | Y |Maximum number of owned tiles that can be travelled|
# |ap            |uint  | Y |?|
# |ambidextrous  |uint  | N |?|
# |mounted       |flag  | N |?|
# |reinvigoration|int   | N |?|
# |leader        |uint  | Y |?|
# |undeadleader  |uint  | N |?|
# |magicleader   |uint  | N |?|
# |startage      |?     | N |?|
# |maxage        |?     | N |?|
# |hand     |uint| Y |?|
# |head     |uint| Y |?|
# |body     |uint| Y |?|
# |foot     |uint| Y |?|
# |misc     |uint| Y |?|
# |pathcost |uint| N |?|
# |startdom |uint| N |?|
# |inn      |uint| N |?|
# |F        |uint| N |?|
# |A        |uint| N |?|
# |W        |uint| N |?|
# |E        |uint| N |?|
# |S        |uint| N |?|
# |D        |uint| N |?|
# |N        |uint| N |?|
# |B        |uint| N |?|
# |H        |uint| N |?|
# |rand1    |uint| N |?|
# |nbr1     |uint| N |?|
# |link1    |uint| N |?|
# |mask1    |uint| N |?|
# |rand2    |uint| N |?|
# |nbr2     |uint| N |?|
# |link2    |uint| N |?|
# |mask2    |uint| N |?|
# |rand3    |uint| N |?|
# |nbr3     |uint| N |?|
# |link3    |uint| N |?|
# |mask3    |uint| N |?|
# |rand4    |uint| N |?|
# |nbr4     |uint| N |?|
# |link4    |uint| N |?|
# |mask4    |uint| N |?|
# |mind     | ?? | N |Unused*|
# |demon    |bool| N |?|
# |sailingshipsize   |uint | N |?|
# |sailingmaxunitsize|int* | N |?|
# |stealthy |uint| N |?|
# |illusion |flag| N |?|
# |spy      |uint| N |?|
# |assassin |uint| N |?|
# |patience |uint| N |?|
# |seduce   |uint| N |?|
# |succubus |uint| N |?|
# |corrupt  |flag| N |?|
# |heal     |flag| N |?|
# |immortal |flag| N |?|
# |reinc    |flag| N |?|
# |noheal   |flag| N |?|
# |neednoteat      |flag| N |?|
# |homesick        |uint| N |?|
# |undisciplined   |flag| N |?|
# |formationfighter|flag| N |?|
# |slave           |uint| N |?|
# |standard        |flag| N |?|
# |inspirational   |int | N |?|
# |taskmaster      |uint| N |?|
# |beastmaster     |uint| N |?|
# |bodyguard       |uint| N |?|
# |waterbreathing  |uint| N |?|
# |iceprot         |uint| N |?|
# |invulnerable    |uint| N |?|
# |slashres        |flag| N |?|
# |bluntres        |flag| N |?|
# |pierceres       |flag| N |?|
# |shockres        |int | N |?|
# |fireres         |int | N |?|
# |coldres         |int | N |?|
# |poisonres       |int | N |?|
# |voidsanity      |uint| N |?|
# |darkvision      |uint| N |?|
# |blind           |flag| N |?|
# |animalawe       |uint| N |?|
# |awe             |uint| N |?|
# |halt            |uint| N |?|
# |fear            |uint| N |?|
# |berserk         |uint| N |?|
# |cold            |uint| N |?|
# |heat            |uint| N |?|
# |fireshield      |uint| N |?|
# |banefireshield  |uint| N |?|
# |damagerev       |uint| N |?|
# |poisoncloud     |uint| N |?|
# |diseasecloud    |uint| N |?|
# |slimer          |uint| N |?|
# |mindslime       |uint| N |?|
# |disbel          |uint| N |Unique to Bodhisattva of Mercy(2457)|
# |reform          |uint| N |Unique to Worm Mage(2217)|
# |regeneration    |uint| N |?|
# |reanimator      |uint| N |?|
# |barbs           |flag| N |?|
# |petrify         |flag| N |Unique to Gorgon(138)|
# |eyeloss         |flag| N |?|
# |ethereal        |flag| N |?|
# |ethtrue         |flag| N |?|
# |deathcurse      |flag| N |?|
# |trample         |flag| N |?|
# |trampswallow    |flag| N |?|
# |stormpower      |uint| N |?|
# |firepower       |uint| N |?|
# |coldpower       |uint| N |?|
# |darkpower       |uint| N |?|
# |chaospower   |uint| N |?|
# |magicpower   |uint| N |?|
# |winterpower  |uint| N |?|
# |springpower  |uint| N |?|
# |summerpower  |uint| N |?|
# |fallpower    |uint| N |?|
# |forgebonus   | ?? | N |Unused|
# |fixforgebonus|int | N |?|
# |mastersmith  |flag| N |?|
# |resources    |uint| N |?|
# |autohealer   |uint| N |?|
# |autodishealer|uint| N |?|
# |alch         |uint| N |?|
# |nobadevents  |uint| N |?|
# |event        |int | N |?|
# |insane       |uint| N |?|
# |shatteredsoul|uint| N |?|
# |leper        |uint| N |?|
# |taxcollector |flag| N |?|
# |gem          | ?? | N |Unused|
# |chaosrec     |int | N |?|
# |pillagebonus |int | N |?|
# |patrolbonus  |int | N |?|
# |castledef    |int | N |?|
# |siegebonus   |int | N |?|
# |incprovdef   |flag| N |Unique to Eunuch(805)|
# |supplybonus  |int | N |?|
# |incunrest    |int | N |?|
# |popkill      |int | N |?|
# |researchbonus|int | N |?|
# |drainimmune  |flag| N |?|
# |inspiringres |uint| N |?|
# |douse        |uint| N |?|
# |sacr         |uint| N |?|
# |ivylord      |uint| N |?|
# |crossbreeder |uint| N |?|
# |makepearls   |uint| N |?|
# |pathboost    | ?? | N |Unused|
# |voidsum      |uint| N |?|
# |heretic      |uint| N |?|
# |elegist      |uint| N |?|
# |shapechange  |uint| N |?|
# |firstshape   |uint| N |?|
# |secondshape  |uint| N |?|
# |secondtmpshape|uint| N |?|
# |landshape    |uint| N |?|
# |watershape   |uint| N |?|
# |forestshape  |uint| N |?|
# |plainshape   |uint| N |?|
# |unique       |flag| N |Balam of the North(2767) has value -1|
# |nametype     |uint| N |?|
# |summon       |uint| N |?|
# |n_summon     |uint| N |?|
# |autosum      |uint| N |?|
# |batstartsum1 |uint| N |?|
# |batstartsum2 |uint| N |?|
# |domsummon    |uint| N |?|
# |bloodvengeance  |uint| N |Unique to Angel of Fury(1369)|
# |bringeroffortune|int | N |?|
# |realm1        |uint| N |?|
# |realm2        |uint| N |?|
# |realm3        |uint| N |Unused|
# |batstartsum3  |uint| N |Only used by Irminsul(2234)|
# |batstartsum4  |uint| N |Unused|
# |batstartsum5  |uint| N |Unused|
# |batstartsum1d6|uint| N |?|
# |batstartsum2d6|uint| N |?|
# |batstartsum3d6|uint| N |?|
# |batstartsum4d6|uint| N |?|
# |batstartsum5d6|uint| N |Only used by Teotl of the Underworld(2444)|
# |batstartsum6d6|uint| N |Only used by Lord of the Hunt(780)|
# |turmoilsummon |uint| N |?|
# |coldsummon    |uint| N |Unique to Son of Niefel(605)|
# |scalewalls    |flag| N |?|
# |baseleadership|uint| N |?|
# |explodeondeath|uint| N |?|
# |startaff      |uint| N |?|
# |uwregen       |uint| N |?|
# |shrinkhp      |uint| N |?|
# |growhp        |uint| N |?|
# |transformation|int | N |Either -1 or 1|
# |startingaff   |uint| N |?|
# |fixedresearch |uint| N |?|
# |divineins     |flag| N |?|
# |lamiabonus    |uint| N |?|
# |preanimator   |uint| N |?|
# |dreanimator   |uint| N |?|
# |mummify       |uint| N |?|
# |onebattlespell|uint| N |?|
# |fireattuned   |uint| N |?|
# |airattuned	   |uint| N |?|
# |waterattuned  |uint| N |?|
# |earthattuned  |uint| N |?|
# |astralattuned |uint| N |?|
# |deathattuned  |uint| N |Only used by Dire Wolf(1224)|
# |natureattuned |uint| N |?|
# |bloodattuned  |uint| N |Unused|
# |magicboostF   |int | N |?|
# |magicboostA   |int | N |?|
# |magicboostW   |int | N |?|
# |magicboostE   |int | N |?|
# |magicboostS   |int | N |?|
# |magicboostD   |int | N |?|
# |magicboostN   |int | N |?|
# |magicboostALL |int | N |?|
# |eyes          |uint| N |?|
# |heatrec       |flag| N |One value has 0|
# |coldrec       |flag| N |One value has 0|
# |spreadchaos   |flag| N |?|
# |spreaddeath   |flag| N |?|
# |corpseeater   |uint| N |?|
# |poisonskin    |uint| N |Always 20|
# |bug           |flag| N |?|
# |uwbug         |flag| N |?|
# |spreadorder   |flag| N |?|
# |spreadgrowth  |flag| N |?|
# |spreaddom     |flag| N |?|
# |reform.1      |uint| N |Unique to Worm Mage(2217)|
# |battlesum5    |uint| N |Unique to Worm Mage(2217)|
# |acidsplash    |uint| N |Unique to Gelatinous Cube	(2159)|
# |drake         |flag| N |?|
# |prophetshape  |uint| N |?|
# |horror        |uint| N |?|
# |enchrebate50  |uint| N |Unique to Siren(1054,1055)|
# |heroarrivallimit|uint| N |?|
# |sailsize      |uint| N |Always 2 (assume default 1?)|
# |uwdamage      |uint| N |Always 100 (Percentage mask?)|
# |landdamage    |uint| N |Always 100 (Percentage mask?)|
# |test          | ?? | N |Unused|
#
#
# |xxx|xxx|xxx|
# |---|---|---|
# |xxx|xxx|xxx|

# %%
calculate_sparsity = lambda serieslike : serieslike.count() / serieslike.size
printable_sparsity = lambda serieslike : round(calculate_sparsity(serieslike), 4) * 100

# %%
#baseu.loc[:,'rand1':].agg(printable_sparsity)
baseu.loc[:,'spreadorder':].describe()
# Out:
#        spreadorder  spreadgrowth  spreaddom  reform.1  battlesum5  acidsplash  \
# count          4.0           3.0       10.0       1.0         1.0         1.0
# mean           1.0           1.0        1.0      75.0      2218.0        12.0
# std            0.0           0.0        0.0       NaN         NaN         NaN
# min            1.0           1.0        1.0      75.0      2218.0        12.0
# 25%            1.0           1.0        1.0      75.0      2218.0        12.0
# 50%            1.0           1.0        1.0      75.0      2218.0        12.0
# 75%            1.0           1.0        1.0      75.0      2218.0        12.0
# max            1.0           1.0        1.0      75.0      2218.0        12.0
#
#        drake  prophetshape     horror  enchrebate50  heroarrivallimit  \
# count    7.0      15.00000  17.000000           2.0         49.000000
# mean     1.0     330.60000   1.941176          50.0         13.979592
# ...

# %%
baseu[baseu['landdamage'].notnull()].loc[:,['id','name', 'landdamage']]
# Out:
#         id                   name  landdamage
# 2829  2847  Protogenos of the Sea       100.0
# 2830  2848      Father of the Sea       100.0

# %% [markdown]
# ## Setup
# Run this everytime the kernel starts

# %%
# Standard imports
import os
from pathlib import Path
import sys
import math
import random
import shutil

# Package imports
import pandas as pd
import numpy as np
from IPython.display import display
import h5py
import plotly
from pandas.api.types import CategoricalDtype

default_raw_data_path = Path('../../repos/dom4inspector/gamedata/')

class dom4data:
    loaded = False
    
    BaseU = 0
    
    def is_loaded():
        return dom4data.loaded
    def unload():
        dom4data.BaseU = 0
        dom4data.loaded = False
    def load(raw_data_path=default_raw_data_path):

        if dom4data.loaded:
            dom4data.unload()
        
        
        resolve = lambda name: raw_data_path / (name + ".csv")

        encoding = 'ISO-8859–1'
        sep = '\t'

        flag_converter = lambda x: x != ""

        dom4data.BaseU = pd.read_csv(resolve("BaseU"), encoding=encoding, sep=sep,
                                    dtype={
                                        'id': int, 'name' : str,
                                        # Equipment references
                                        'wpn1':'Int64','wpn2':'Int64','wpn3':'Int64','wpn4':'Int64',
                                        'wpn5':'Int64','wpn6':'Int64','wpn7':'Int64',
                                        'armor1':'Int64','armor2':'Int64','armor3':'Int64','armor4':'Int64',
                                        'startage' : float, 'allrange' : str, 'startitem' : str,

                                        'size':'category',


                                          },

                                    converters={
                                        #Flags
                                        'holy': flag_converter,
                                        'inquisitor': flag_converter,
                                        'inanimate': flag_converter,
                                        'undead': flag_converter,
                                        'magicbeing': flag_converter,
                                        'stonebeing': flag_converter,
                                        'animal': flag_converter,
                                        'coldblood': flag_converter,
                                        'female': flag_converter,
                                        'forestsurvival': flag_converter,
                                        'mountainsurvival': flag_converter,
                                        'wastesurvival': flag_converter,
                                        'swampsurvival': flag_converter,
                                        'cavesurvival': flag_converter,
                                        'aquatic': flag_converter,
                                        'amphibian': flag_converter,
                                        'pooramphibian': flag_converter,
                                        'float': flag_converter,
                                        'flying': flag_converter,
                                        'stormimmune': flag_converter,
                                        'teleport': flag_converter,
                                        'immobile': flag_converter,
                                        'noriverpass': flag_converter,
                                    },

                                    na_values={'startage':["120 ? 320"]})

# %%
dom4data.load(Path("G:/Repos/dom4inspector-gh-pages/gamedata"))
baseu = dom4data.BaseU

# %%
value_check = lambda table, column: data[table][data[table][column].notnull()][column]
flag_check = lambda table, column: len(set(value_check(table, column))) == 1
print(flag_check('baseu','aquatic'))
print(flag_check('baseu','amphibian'))
print(flag_check('baseu','pooramphibian'))
print(flag_check('baseu','float'))
print(flag_check('baseu','flying'))
print(flag_check('baseu','stormimmune'))
print(flag_check('baseu','teleport'))
print(flag_check('baseu','immobile'))
print(flag_check('baseu','noriverpass'))
print(flag_check('baseu','coldblood'))
print("")
print(value_check('baseu', 'coldblood'))
data['baseu']['mind']
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
#
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2889    False
# 2890    False
# 2891    False
# 2892    False
# 2893    False
# 2894    False
# 2895    False
# 2896    False
# 2897    False
# 2898    False
# 2899    False
# 2900    False
# 2901    False
# 2902    False
# 2903    False
# 2904    False
# 2905    False
# 2906    False
# 2907    False
# 2908    False
# 2909    False
# 2910    False
# 2911    False
# 2912    False
# 2913    False
# 2914    False
# ...

# %% [markdown]
# ## Unit Clustering

# %%
clusters = []
new_clusters = []

def create_cluster():
    cluster = {
        'size' : 0,
        'str':0
    }
    return cluster
    
def create_random_cluster():
    cluster = {
        'size' : random.randrange(7),
        'str': random.randrange(50)
    }
    return cluster

# %%
def pred1(row_label):
    global clusters
    row = dm.data['BaseU'].loc[row_label]
    size = row['size']
    strength = row['str']
    cur = 0
    for i in range(1,len(clusters)):
        if abs(clusters[i]['size'] - size) < abs(clusters[cur]['size'] - size):
            cur = i
    return str(cur)

# %%
def cluster(k,predicate=pred1):
    global clusters
    if not dm.is_open():
        dm.open()
    
    if len(clusters) == 0:
        # Create random clusters
        for i in range(k):
            clusters.append(create_random_cluster())
    
    BaseU = dm.data['BaseU']
    groups = BaseU.groupby(predicate)
    return groups

# %%
test = cluster(6)

# %%
print(test.groups)

# %%
def calculate_cluster(row):
    global new_clusters
    return 0

# %%
def recalculate_clusters(groups):
    global clusters
    global new_clusters
    
    new_clusters = []
    for i in range(len(clusters)):
        new_clusters.append(create_cluster())
    
    ga = groups.aggregate({'size':np.mean,'str':np.mean})
    
    return ga

# %%
print(test.groups)
ga = recalculate_clusters(test)
print(new_clusters)
print(ga)

# %%
ga.iloc[0]

# %%
BaseU['str'].min()

# %% [markdown]
# ## Box Plots showing relation between size and str

# %%
box_groups = BaseU[{'size','str'}].groupby('size')
box_groups.boxplot(subplots=False,figsize={16,15})
box_groups.str.groups

# %%
BaseU[{'size','str'}]
